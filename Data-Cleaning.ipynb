# %%
import pandas as pd
import numpy as np

# %%
df_2017 = pd.read_csv("/Users/snowe/Desktop/BDA600 Course Project/Data/2017.csv",header = None)

# %%
df_2018 = pd.read_csv("/Users/snowe/Desktop/BDA600 Course Project/Data/2018.csv",header = None)
df_2019 = pd.read_csv("/Users/snowe/Desktop/BDA600 Course Project/Data/2019.csv",header = None)
df_2020 = pd.read_csv("/Users/snowe/Desktop/BDA600 Course Project/Data/2020.csv",header = None)
df_2021 = pd.read_csv("/Users/snowe/Desktop/BDA600 Course Project/Data/2021.csv",header = None)

# %%
df_2017 = df_2017.drop(df_2017.columns[[0]], axis=1)

# %%
df_2017['Survey Year'] = 2017
df_2017.columns = range(df_2017.columns.size)

# %%
df_2017.info(verbose=False)
df_2017.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Columns: 123 entries, 0 to 122
# dtypes: int64(1), object(122)
# memory usage: 727.6+ KB
#                                        0    \
# 0  <strong>Are you self-employed?</strong>
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#                                                  1    \
# 0  How many employees does your company or organi...
# 1                                            100-500
# 2                                            100-500
# 3                                               6-25
# 4                                     More than 1000
#
#                                                  2    \
# 0  Is your employer primarily a tech company/orga...
# 1                                                  1
# 2                                                  1
# ...

# %%
df_2018 = df_2018.drop(df_2018.columns[[0]], axis=1)

# %%
df_2018['Survey Year'] = 2018
df_2018.columns = range(df_2018.columns.size)

# %%
df_2018.info(verbose=False)
df_2018.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Columns: 123 entries, 0 to 122
# dtypes: int64(1), object(122)
# memory usage: 401.8+ KB
#                                        0    \
# 0  <strong>Are you self-employed?</strong>
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#                                                  1    \
# 0  How many employees does your company or organi...
# 1                                     More than 1000
# 2                                     More than 1000
# 3                                               6-25
# 4                                               6-25
#
#                                                  2    \
# 0  Is your employer primarily a tech company/orga...
# 1                                                  1
# 2                                                  1
# ...

# %%
df_2019
# Out:
#                            0   \
# 0    *Are you self-employed?*
# 1                       FALSE
# 2                       FALSE
# 3                       FALSE
# 4                       FALSE
# ..                        ...
# 348                     FALSE
# 349                      TRUE
# 350                      TRUE
# 351                     FALSE
# 352                     FALSE
#
#                                                     1   \
# 0    How many employees does your company or organi...
# 1                                               26-100
# 2                                               26-100
# 3                                               26-100
# 4                                              100-500
# ..                                                 ...
# 348                                     More than 1000
# 349                                                NaN
# 350                                                NaN
# ...

# %%
df_2019['Survey Year'] = 2019
df_2019.columns = range(df_2019.columns.size)

# %%
df_2019.info(verbose=False)
df_2019.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Columns: 83 entries, 0 to 82
# dtypes: int64(1), object(82)
# memory usage: 229.0+ KB
#                          0   \
# 0  *Are you self-employed?*
# 1                     FALSE
# 2                     FALSE
# 3                     FALSE
# 4                     FALSE
#
#                                                   1   \
# 0  How many employees does your company or organi...
# 1                                             26-100
# 2                                             26-100
# 3                                             26-100
# 4                                            100-500
#
#                                                   2   \
# 0  Is your employer primarily a tech company/orga...
# 1                                               TRUE
# 2                                               TRUE
# 3                                               TRUE
# ...

# %%
df_2020 = df_2020.drop(df_2020.columns[[0]], axis=1)
df_2020['Survey Year'] = 2020
df_2020.columns = range(df_2020.columns.size)

# %%
df_2020.info(verbose=False)
df_2020.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Columns: 120 entries, 0 to 119
# dtypes: int64(1), object(119)
# memory usage: 169.8+ KB
#                         0    \
# 0  *Are you self-employed?*
# 1                         1
# 2                         1
# 3                         1
# 4                         1
#
#                                                  1    \
# 0  How many employees does your company or organi...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  2    \
# 0  Is your employer primarily a tech company/orga...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df_2021 = df_2021.drop(df_2021.columns[[0]],axis=1)
df_2021['Survey Year'] = 2021
df_2021.columns = range(df_2021.columns.size)

# %%
df_2021.info(verbose=False)
df_2021.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Columns: 124 entries, 0 to 123
# dtypes: int64(1), object(123)
# memory usage: 128.0+ KB
#                         0    \
# 0  *Are you self-employed?*
# 1                         0
# 2                         0
# 3                         0
# 4                         1
#
#                                                  1    \
# 0  How many employees does your company or organi...
# 1                                             26-100
# 2                                           500-1000
# 3                                            100-500
# 4                                                NaN
#
#                                                  2    \
# 0  Is your employer primarily a tech company/orga...
# 1                                                  1
# 2                                                  1
# 3                                                  1
# ...

# %%
df_2017_GQ = df_2017.iloc[:,np.r_[0:6,111:116,117:119,-1]]
df_2017_GQ.columns = range(df_2017_GQ.columns.size)
df_2017_GQ
# Out:
#                                           0   \
# 0    <strong>Are you self-employed?</strong>
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 752                                        0
# 753                                        0
# 754                                        1
# 755                                        0
# 756                                        1
#
#                                                     1   \
# 0    How many employees does your company or organi...
# 1                                              100-500
# 2                                              100-500
# 3                                                 6-25
# 4                                       More than 1000
# ..                                                 ...
# ...

# %%
df_2018_GQ = df_2018.iloc[:,np.r_[0:6,111:116,117:119,-1]]
df_2018_GQ.columns = range(df_2018_GQ.columns.size)
df_2018_GQ
# Out:
#                                           0   \
# 0    <strong>Are you self-employed?</strong>
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 413                                        0
# 414                                        0
# 415                                        0
# 416                                        0
# 417                                        0
#
#                                                     1   \
# 0    How many employees does your company or organi...
# 1                                       More than 1000
# 2                                       More than 1000
# 3                                                 6-25
# 4                                                 6-25
# ..                                                 ...
# ...

# %%
df_2019_GQ = df_2019.iloc[:,np.r_[0:6,75:83,-1]]
df_2019_GQ.columns = range(df_2019_GQ.columns.size)
df_2019_GQ = df_2019_GQ.drop(df_2019_GQ.columns[[14]],axis=1)
df_2019_GQ
# Out:
#                            0   \
# 0    *Are you self-employed?*
# 1                       FALSE
# 2                       FALSE
# 3                       FALSE
# 4                       FALSE
# ..                        ...
# 348                     FALSE
# 349                      TRUE
# 350                      TRUE
# 351                     FALSE
# 352                     FALSE
#
#                                                     1   \
# 0    How many employees does your company or organi...
# 1                                               26-100
# 2                                               26-100
# 3                                               26-100
# 4                                              100-500
# ..                                                 ...
# 348                                     More than 1000
# 349                                                NaN
# 350                                                NaN
# ...

# %%
df_2020_GQ = df_2020.iloc[:,np.r_[0:6,111:116,117:119,-1]]
df_2020_GQ.columns = range(df_2020_GQ.columns.size)
df_2020_GQ
# Out:
#                            0   \
# 0    *Are you self-employed?*
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ..                        ...
# 176                         0
# 177                         0
# 178                         0
# 179                         0
# 180                         0
#
#                                                     1   \
# 0    How many employees does your company or organi...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 176                                     More than 1000
# 177                                             26-100
# 178                                            100-500
# ...

# %%
df_2021_GQ = df_2021.iloc[:,np.r_[0:6,111:116,117:119,-1]]
df_2021_GQ.columns = range(df_2021_GQ.columns.size)
df_2021_GQ
# Out:
#                            0   \
# 0    *Are you self-employed?*
# 1                           0
# 2                           0
# 3                           0
# 4                           1
# ..                        ...
# 127                         0
# 128                         0
# 129                         1
# 130                         1
# 131                         0
#
#                                                     1   \
# 0    How many employees does your company or organi...
# 1                                               26-100
# 2                                             500-1000
# 3                                              100-500
# 4                                                  NaN
# ..                                                 ...
# 127                                             26-100
# 128                                            100-500
# 129                                                NaN
# ...

# %%
GQ = [df_2017_GQ,df_2018_GQ,df_2019_GQ,df_2020_GQ,df_2021_GQ]
df_General_Questions = pd.concat(GQ)

# %%
df_General_Questions.insert(0, '0', df_General_Questions.pop(13))

# %%
df_General_Questions.columns = range(df_General_Questions.columns.size)
df_General_Questions = df_General_Questions.rename(columns={0: 'Survey Year'})
df_General_Questions
# Out:
#      Survey Year                                        1  \
# 0           2017  <strong>Are you self-employed?</strong>
# 1           2017                                        0
# 2           2017                                        0
# 3           2017                                        0
# 4           2017                                        0
# ..           ...                                      ...
# 127         2021                                        0
# 128         2021                                        0
# 129         2021                                        1
# 130         2021                                        1
# 131         2021                                        0
#
#                                                      2  \
# 0    How many employees does your company or organi...
# 1                                              100-500
# 2                                              100-500
# ...

# %%
#Create dataframe for Question 4

# %%
#df_2017_Q4 = df_2017.iloc[:,np.r_[97:99,-1]]
#df_2018_Q4 = df_2018.iloc[:,np.r_[97:99,-1]]
#df_2019_Q4 = df_2019.iloc[:,np.r_[61:63,-1]]
#df_2020_Q4 = df_2020.iloc[:,np.r_[97:99,-1]]
#df_2021_Q4 = df_2021.iloc[:,np.r_[97:99,-1]]

# %%
df_2017_Q4 = df_2017.iloc[:,97:99]
df_2018_Q4 = df_2018.iloc[:,97:99]
df_2019_Q4 = df_2019.iloc[:,61:63]
df_2020_Q4 = df_2020.iloc[:,97:99]
df_2021_Q4 = df_2021.iloc[:,97:99]

# %%
df_2017_Q4.columns = range(df_2017_Q4.columns.size)
df_2018_Q4.columns = range(df_2018_Q4.columns.size)
df_2019_Q4.columns = range(df_2019_Q4.columns.size)
df_2020_Q4.columns = range(df_2020_Q4.columns.size)
df_2021_Q4.columns = range(df_2021_Q4.columns.size)

# %%
Q4 = [df_2017_Q4,df_2018_Q4,df_2019_Q4,df_2020_Q4,df_2021_Q4]
df_Q4 = pd.concat(Q4)

# %%
df_Q4
# Out:
#                                                      0  \
# 0    Would you bring up your mental health with a p...
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 127                                                 No
# 128                                                 No
# 129                                                 No
# 130                                                 No
# 131                                                 No
#
#                                                      1
# 0                                      Why or why not?
# 1                I'd be worried they wouldn't hire me
# 2    mental health issues are stigmatised and misun...
# 3                                               stigma
# ...

# %%
#df_Q4.insert(0, '0', df_Q4.pop(2))

# %%
#df_Q4.columns = range(df_Q4.columns.size)
#df_Q4 = df_Q4.rename(columns={0: 'Survey Year'})
#df_Q4

# %%
result = pd.concat([df_General_Questions, df_Q4], axis=1, join='inner')
result
# Out:
#      Survey Year                                        1  \
# 0           2017  <strong>Are you self-employed?</strong>
# 1           2017                                        0
# 2           2017                                        0
# 3           2017                                        0
# 4           2017                                        0
# ..           ...                                      ...
# 127         2021                                        0
# 128         2021                                        0
# 129         2021                                        1
# 130         2021                                        1
# 131         2021                                        0
#
#                                                      2  \
# 0    How many employees does your company or organi...
# 1                                              100-500
# 2                                              100-500
# ...

# %%
result.columns = range(result.columns.size)
result
# Out:
#        0                                        1   \
# 0    2017  <strong>Are you self-employed?</strong>
# 1    2017                                        0
# 2    2017                                        0
# 3    2017                                        0
# 4    2017                                        0
# ..    ...                                      ...
# 127  2021                                        0
# 128  2021                                        0
# 129  2021                                        1
# 130  2021                                        1
# 131  2021                                        0
#
#                                                     2   \
# 0    How many employees does your company or organi...
# 1                                              100-500
# 2                                              100-500
# 3                                                 6-25
# 4                                       More than 1000
# ...

# %%
import os
import re

# %%
result.loc[:,15]
# Out:
# 0                                        Why or why not?
# 1                  I'd be worried they wouldn't hire me
# 2      mental health issues are stigmatised and misun...
# 3                                                 stigma
# 4                                  Might hurt my chances
#                              ...
# 127    I cannot see the point of bringing it during t...
# 128    If can affect my work and I don't know how emp...
# 129                                                  NaN
# 130                               It will impact the job
# 131    Because it is taboo and not that much understa...
# Name: 15, Length: 1841, dtype: object

# %%
#remove punctuation
result['answer_processed'] = \
result.loc[:,15].map(lambda x: re.sub('[,\.!?]', '', str(x)))

# %%
#convert the titles to lowercase
result['answer_processed'] = \
result['answer_processed'].map(lambda x: x.lower())

# %%
#print out the first rows of answer_processed
result['answer_processed'].head()
# Out:
# 0                                       why or why not
# 1                i'd be worried they wouldn't hire me
# 2    mental health issues are stigmatised and misun...
# 3                                               stigma
# 4                                might hurt my chances
# Name: answer_processed, dtype: object

# %%
from platform import python_version
python_version()
# Out:
# '3.8.5'

# %%
from wordcloud import WordCloud

# %%
# Join the different processed titles together.
long_string = ','.join(list(result['answer_processed'].values))
# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
# Generate a word cloud
wordcloud.generate(long_string)
# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FCAC7D95FA0>

# %%
conda install -c conda-forge gensim
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - gensim
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gensim-3.8.3               |   py38hc84c608_2        22.7 MB  conda-forge
#     openssl-1.1.1h             |       haf1e3a3_0         1.9 MB  conda-forge
#     smart_open-5.2.1           |     pyhd8ed1ab_0          43 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        24.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   gensim             conda-forge/osx-64::gensim-3.8.3-py38hc84c608_2
# ...
